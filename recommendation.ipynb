# %% [markdown]
# <a href="https://colab.research.google.com/github/CHAITANYA2605/recommendation_movielens/blob/main/recommendation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import tensorflow as tf

# %%
movie=pd.read_csv("/content/movie.csv")
movie.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
rating_movie=pd.read_csv("/content/rating.csv")
rating_movie.head()
# Out:
#    userId  movieId  rating            timestamp
# 0       1        2     3.5  2005-04-02 23:53:47
# 1       1       29     3.5  2005-04-02 23:31:16
# 2       1       32     3.5  2005-04-02 23:33:39
# 3       1       47     3.5  2005-04-02 23:32:07
# 4       1       50     3.5  2005-04-02 23:29:40

# %%
link=pd.read_csv("/content/link.csv")
link.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
tags=pd.read_csv("/content/tag.csv")
tags.head()
# Out:
#    userId  movieId            tag            timestamp
# 0      18     4141    Mark Waters  2009-04-24 18:19:40
# 1      65      208      dark hero  2013-05-10 01:41:18
# 2      65      353      dark hero  2013-05-10 01:41:19
# 3      65      521  noir thriller  2013-05-10 01:39:43
# 4      65      592      dark hero  2013-05-10 01:41:18

# %%
genomescore=pd.read_csv("/content/genome_scores.csv")
genomescore.head()
# Out:
#    movieId  tagId  relevance
# 0        1      1    0.02500
# 1        1      2    0.02500
# 2        1      3    0.05775
# 3        1      4    0.09675
# 4        1      5    0.14675

# %%
genometags=pd.read_csv("/content/genome_tags.csv")
genometags.head()
# Out:
#    tagId           tag
# 0      1           007
# 1      2  007 (series)
# 2      3  18th century
# 3      4         1920s
# 4      5         1930s

# %%
import ast

# %%
movie.dropna(inplace=True)
movie.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movie['genres'] = movie['genres'].apply(lambda x: x.split('|'))

# %%
movie.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                               genres
# 0  [Adventure, Animation, Children, Comedy, Fantasy]
# 1                     [Adventure, Children, Fantasy]
# 2                                  [Comedy, Romance]
# 3                           [Comedy, Drama, Romance]
# 4                                           [Comedy]

# %%
movie.tail(10)
# Out:
#        movieId                                              title  \
# 27268   131241                           Ants in the Pants (2000)
# 27269   131243                Werner - Gekotzt wird später (2003)
# 27270   131248                              Brother Bear 2 (2006)
# 27271   131250                              No More School (2000)
# 27272   131252  Forklift Driver Klaus: The First Day on the Jo...
# 27273   131254                       Kein Bund für's Leben (2007)
# 27274   131256                      Feuer, Eis & Dosenbier (2002)
# 27275   131258                                 The Pirates (2014)
# 27276   131260                                Rentun Ruusu (2001)
# 27277   131262                                   Innocence (2014)
#
#                                                   genres
# 27268                                  [Comedy, Romance]
# 27269                                [Animation, Comedy]
# 27270  [Adventure, Animation, Children, Comedy, Fantasy]
# 27271                                           [Comedy]
# 27272                                   [Comedy, Horror]
# 27273                                           [Comedy]
# 27274                                           [Comedy]
# 27275                                        [Adventure]
# 27276                               [(no genres listed)]
# 27277                       [Adventure, Fantasy, Horror]

# %%
content_movie=movie[['movieId','title','genres']]
content_movie.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                               genres
# 0  [Adventure, Animation, Children, Comedy, Fantasy]
# 1                     [Adventure, Children, Fantasy]
# 2                                  [Comedy, Romance]
# 3                           [Comedy, Drama, Romance]
# 4                                           [Comedy]

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000,stop_words='english')

# %%
content_movie['genres'] = content_movie['genres'].apply(lambda x: " ".join(x))
content_movie.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure Animation Children Comedy Fantasy
# 1                   Adventure Children Fantasy
# 2                               Comedy Romance
# 3                         Comedy Drama Romance
# 4                                       Comedy

# %%
vector = cv.fit_transform(content_movie['genres']).toarray()

# %%
vector.shape
# Out:
# (27278, 23)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vector)

# %%
similarity
# Out:
# array([[1.        , 0.77459667, 0.31622777, ..., 0.4472136 , 0.        ,
#         0.51639778],
#        [0.77459667, 1.        , 0.        , ..., 0.57735027, 0.        ,
#         0.66666667],
#        [0.31622777, 0.        , 1.        , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.4472136 , 0.57735027, 0.        , ..., 1.        , 0.        ,
#         0.57735027],
#        [0.        , 0.        , 0.        , ..., 0.        , 1.        ,
#         0.        ],
#        [0.51639778, 0.66666667, 0.        , ..., 0.57735027, 0.        ,
#         1.        ]])

# %%
# def recommend(movie):
#     # Check if the movie exists in the DataFrame
#     if movie not in content_movie['title'].values:
#         print(f"Movie '{movie}' not found in the dataset.")
#         return

#     # Get the index of the movie
#     index = content_movie[content_movie['title'] == movie].index[0]

#     # Compute the distances
#     distances = sorted(list(enumerate(similarity[index])), reverse=True, key=lambda x: x[1])

#     # Print the top 5 recommended movies
#     for i in distances[1:10]:
#         print(content_movie.iloc[i[0]].title)
#         print(distances)

# %%
def recommend(movie):
    # Check if the movie exists in the DataFrame
    recommendations = []
    if movie not in content_movie['title'].values:
        print(f"Movie '{movie}' not found in the dataset.")
        return

    # Get the index of the movie
    index = content_movie[content_movie['title'] == movie].index[0]

    # Compute the distances
    distances = sorted(list(enumerate(similarity[index])), reverse=True, key=lambda x: x[1])

    # Get the top 5 recommended movies and save them to the list
    for i in distances[1:6]:
        recommendations.append(content_movie.iloc[i[0]].title)
        print(content_movie.iloc[i[0]].title)

# Call the recommend function with a movie title
recommend('Toy Story (1995)')

# Print the first five recommendations
print(recommendations[:5])
# Out:
# Antz (1998)
# Toy Story 2 (1999)
# Adventures of Rocky and Bullwinkle, The (2000)
# Emperor's New Groove, The (2000)
# Monsters, Inc. (2001)
# ['Antz (1998)', 'Toy Story 2 (1999)', 'Adventures of Rocky and Bullwinkle, The (2000)', "Emperor's New Groove, The (2000)", 'Monsters, Inc. (2001)']

# %%
recommend('Toy Story (1995)')

# %%
movie=pd.read_csv("/content/movie.csv")

# %%
df = movie.merge(rating_movie, how="left", on="movieId")

# %%
comment_counts = pd.DataFrame(df["title"].value_counts())
comment_counts.head(20)
# Out:
#                                                     count
# title
# Pulp Fiction (1994)                                  9650
# Forrest Gump (1994)                                  9540
# Silence of the Lambs, The (1991)                     9008
# Shawshank Redemption, The (1994)                     8986
# Jurassic Park (1993)                                 8549
# Star Wars: Episode IV - A New Hope (1977)            7847
# Braveheart (1995)                                    7651
# Terminator 2: Judgment Day (1991)                    7526
# Matrix, The (1999)                                   7346
# Schindler's List (1993)                              7253
# Fugitive, The (1993)                                 7110
# Toy Story (1995)                                     7080
# Apollo 13 (1995)                                     6859
# Independence Day (a.k.a. ID4) (1996)                 6715
# Star Wars: Episode VI - Return of the Jedi (1983)    6711
# Usual Suspects, The (1995)                           6698
# Batman (1989)                                        6609
# Star Wars: Episode V - The Empire Strikes Back ...   6549
# American Beauty (1999)                               6441
# Twelve Monkeys (a.k.a. 12 Monkeys) (1995)            6318

# %%
rare_movies = comment_counts[comment_counts["count"] <= 1000].index
rare_movies
# Out:
# Index(['Blood Diamond (2006)', 'Event Horizon (1997)',
#        'Dog Day Afternoon (1975)', 'Quick and the Dead, The (1995)',
#        'Conan the Barbarian (1982)', 'Panic Room (2002)',
#        'Chariots of Fire (1981)', 'Last Emperor, The (1987)',
#        'Sister Act (1992)', 'Home Alone 2: Lost in New York (1992)',
#        ...
#        'Park Row (1952)', 'Sleeping Beauty, The (La belle endormie) (2010)',
#        'Without Warning (1994)', 'Escape from Dartmoor (1929)',
#        'Reparando (2010)', 'Concursante (2007)', 'Arrangement, The (1969)',
#        'Comanche Moon (2008)', 'Dead Man's Walk (1996)', 'Innocence (2014)'],
#       dtype='object', name='title', length=26535)

# %%
common_movies = df[~df["title"].isin(rare_movies)]
common_movies["title"].nunique()
df["title"].nunique()
# Out:
# 27262

# %%
user_movie_df = common_movies.pivot_table(index=["userId"], columns=["title"], values="rating")
user_movie_df.head()
# Out:
# title   10 Things I Hate About You (1999)  101 Dalmatians (1996)  \
# userId
# 1.0                                   NaN                    NaN
# 2.0                                   NaN                    NaN
# 3.0                                   NaN                    NaN
# 4.0                                   NaN                    NaN
# 5.0                                   NaN                    NaN
#
# title   101 Dalmatians (One Hundred and One Dalmatians) (1961)  \
# userId
# 1.0                                                   NaN
# 2.0                                                   NaN
# 3.0                                                   NaN
# 4.0                                                   NaN
# 5.0                                                   NaN
#
# title   12 Angry Men (1957)  13th Warrior, The (1999)  \
# userId
# 1.0                     NaN                       NaN
# 2.0                     NaN                       NaN
# 3.0                     NaN                       NaN
# 4.0                     NaN                       NaN
# 5.0                     NaN                       NaN
#
# title   2001: A Space Odyssey (1968)  28 Days Later (2002)  300 (2007)  \
# userId
# 1.0                              3.5                   3.5         NaN
# 2.0                              5.0                   NaN         NaN
# 3.0                              5.0                   NaN         NaN
# 4.0                              NaN                   NaN         NaN
# 5.0                              NaN                   NaN         NaN
#
# title   40-Year-Old Virgin, The (2005)  A.I. Artificial Intelligence (2001)  \
# userId
# 1.0                                NaN                                  NaN
# 2.0                                NaN                                  NaN
# 3.0                                NaN                                  NaN
# 4.0                                NaN                                  NaN
# 5.0                                NaN                                  NaN
#
# title   ...  Witness (1985)  Wizard of Oz, The (1939)  \
# userId  ...
# 1.0     ...             NaN                       3.5
# 2.0     ...             NaN                       NaN
# 3.0     ...             4.0                       4.0
# 4.0     ...             NaN                       NaN
# 5.0     ...             NaN                       NaN
#
# title   World Is Not Enough, The (1999)  \
# userId
# 1.0                                 NaN
# 2.0                                 NaN
# 3.0                                 NaN
# 4.0                                 NaN
# 5.0                                 NaN
#
# title   X-Files: Fight the Future, The (1998)  X-Men (2000)  \
# userId
# 1.0                                       NaN           NaN
# 2.0                                       NaN           NaN
# 3.0                                       5.0           NaN
# 4.0                                       NaN           NaN
# 5.0                                       NaN           NaN
#
# title   X2: X-Men United (2003)  You've Got Mail (1998)  \
# userId
# 1.0                         4.0                     NaN
# 2.0                         NaN                     NaN
# 3.0                         NaN                     NaN
# 4.0                         NaN                     NaN
# 5.0                         NaN                     NaN
#
# title   Young Frankenstein (1974)  Young Guns (1988)  Zoolander (2001)
# userId
# 1.0                           4.0                NaN               NaN
# 2.0                           NaN                NaN               NaN
# 3.0                           5.0                NaN               NaN
# 4.0                           NaN                NaN               NaN
# 5.0                           NaN                NaN               NaN
#
# [5 rows x 727 columns]

# %%
user_movie_df.shape
user_movie_df.columns
# Out:
# Index(['10 Things I Hate About You (1999)', '101 Dalmatians (1996)',
#        '101 Dalmatians (One Hundred and One Dalmatians) (1961)',
#        '12 Angry Men (1957)', '13th Warrior, The (1999)',
#        '2001: A Space Odyssey (1968)', '28 Days Later (2002)', '300 (2007)',
#        '40-Year-Old Virgin, The (2005)', 'A.I. Artificial Intelligence (2001)',
#        ...
#        'Witness (1985)', 'Wizard of Oz, The (1939)',
#        'World Is Not Enough, The (1999)',
#        'X-Files: Fight the Future, The (1998)', 'X-Men (2000)',
#        'X2: X-Men United (2003)', 'You've Got Mail (1998)',
#        'Young Frankenstein (1974)', 'Young Guns (1988)', 'Zoolander (2001)'],
#       dtype='object', name='title', length=727)

# %%
movie_name1 = "Toy Story (1995)"
movie_name = user_movie_df[movie_name1]
user_movie_df.corrwith(movie_name).sort_values(ascending=False).head(10)
# Out:
# title
# Toy Story (1995)                                          1.000000
# Toy Story 2 (1999)                                        0.757472
# Monsters, Inc. (2001)                                     0.544960
# Bug's Life, A (1998)                                      0.535892
# Finding Nemo (2003)                                       0.535870
# Lion King, The (1994)                                     0.435457
# Incredibles, The (2004)                                   0.434092
# Aladdin (1992)                                            0.429942
# Beauty and the Beast (1991)                               0.414856
# 101 Dalmatians (One Hundred and One Dalmatians) (1961)    0.412392
# dtype: float64

# %%
movie_name = pd.Series(user_movie_df.columns).sample(1).values[0]
movie_name = user_movie_df[movie_name]

# %%
user_movie_df.corrwith(movie_name).sort_values(ascending=False).head(10)
# Out:
# title
# Beetlejuice (1988)                            1.000000
# Edward Scissorhands (1990)                    0.421150
# Ghostbusters (a.k.a. Ghost Busters) (1984)    0.394001
# Ghostbusters II (1989)                        0.383035
# James and the Giant Peach (1996)              0.373983
# Who Framed Roger Rabbit? (1988)               0.368151
# Addams Family, The (1991)                     0.361780
# Bill & Ted's Excellent Adventure (1989)       0.351283
# Little Shop of Horrors (1986)                 0.348454
# Gremlins (1984)                               0.348305
# dtype: float64

# %%
def check_film(keyword, user_movie_df):
    output_list = []
    result = [col for col in user_movie_df.columns if keyword in col]
    output_list.extend(result[:5])
    return output_list

# %%
check_film("Toy Story", user_movie_df)
# Out:
# ['Toy Story (1995)', 'Toy Story 2 (1999)']

# %%
from collections import defaultdict

def top_three_frequent_words(lists_of_words):
    # Dictionary to store word counts
    word_count = defaultdict(int)

    # Iterate over each list in the lists_of_words
    for word_list in lists_of_words:
        # Iterate over each word in the current word list
        for word in word_list:
            word_count[word] += 1

    # Sort the words by their counts in descending order and select the top three
    top_three_words = sorted(word_count, key=word_count.get, reverse=True)[:3]

    return top_three_words

# Example usage:
lists_of_words = [
    recommendations,
    output_list
]
print(top_three_frequent_words(lists_of_words))
# Out:
# ['Toy Story 2 (1999)', 'Antz (1998)', 'Adventures of Rocky and Bullwinkle, The (2000)']

# %%
import json

# Convert the list to a JSON object
json_output = json.dumps(top_three_frequent_words(lists_of_words))

# Print the JSON output
print(json_output)
# Out:
# ["Toy Story 2 (1999)", "Antz (1998)", "Adventures of Rocky and Bullwinkle, The (2000)"]
